# %%
import matplotlib.pyplot as plt
import numpy as np
import pandas as pd

# %%
path = r"D:\workspace-Jwp\python\DataScience\new_lec\mini_project\mini_02\disabled\data"

# %%
df_pop = pd.read_csv(os.path.join(path, "dis_pop.csv"))

# %%
img_path = r"D:\workspace-Jwp\python\DataScience\new_lec\mini_project\mini_02\disabled\Seoul_districts.png"

# %%
seoul = plt.imread(img_path)

# %%
plt.figure(figsize=(10,10))
plt.imshow(seoul)

# %%
n
# Out:
# array([ True])
