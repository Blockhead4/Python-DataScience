# %% [markdown]
# ## Assignment_26

# %%
from keras.models import Sequential
from keras.layers import Dense, Dropout, BatchNormalization
from keras.layers.advanced_activations import LeakyReLU
from keras.utils import np_utils
from keras.optimizers import Adam
from keras.callbacks import ModelCheckpoint, EarlyStopping

from sklearn.preprocessing import MinMaxScaler, LabelEncoder
from sklearn.model_selection import train_test_split

import pandas as pd
import numpy as np
import tensorflow as tf
import matplotlib.pyplot as plt

# %%
# seed 값 설정
seed = 0
np.random.seed(seed)
tf.set_random_seed(seed)

# 데이터 입력
df_pre = pd.read_csv('dataset/wine.csv', header=None)
df = df_pre.sample(frac=1)

dataset = df.values
X = dataset[:,0:11]
Y = dataset[:,11]

Y_encoded = np_utils.to_categorical(Y)

# Train set, Test set
X_train, X_test, y_train, y_test = train_test_split(X, Y_encoded, test_size=0.3)

# %%
y_train.shape
# Out:
# (4547, 10)

# %% [markdown]
# ### Model 1. 3 Dense(RELU)

# %%
# 모델 설정
model = Sequential()
model.add(Dense(256, input_dim=11, activation='relu'))
model.add(Dense(128, activation='relu'))
model.add(Dense(64, activation='relu'))
model.add(Dense(10, activation='softmax'))
model.summary()

#모델 컴파일
model.compile(loss='categorical_crossentropy',
              optimizer='adam',
              metrics=['accuracy'])

# 모델 실행
model.fit(X_train, y_train, epochs=500, batch_size=100)

# 결과 출력
print("\n Accuracy: %.4f" % (model.evaluate(X_train, y_train)[1]))
# Out:
# _________________________________________________________________
# Layer (type)                 Output Shape              Param #
# ...
# dense_25 (Dense)             (None, 256)               3072
# _________________________________________________________________
# dense_26 (Dense)             (None, 128)               32896
# _________________________________________________________________
# dense_27 (Dense)             (None, 64)                8256
# _________________________________________________________________
# dense_28 (Dense)             (None, 10)                650
# ...
# Total params: 44,874
# Trainable params: 44,874
# Non-trainable params: 0
# _________________________________________________________________
# Epoch 1/500
# 4547/4547 [==============================] - 1s 241us/step - loss: 2.4846 - acc: 0.4014
# Epoch 2/500
# 4547/4547 [==============================] - 0s 35us/step - loss: 1.6562 - acc: 0.4319
# Epoch 3/500
# ...

# %%
loss, acc = model.evaluate(X_test, y_test)
print('[ loss: %.4f, acc: %.4f ]' % (loss, acc))
# Out:
# 1950/1950 [==============================] - 0s 33us/step
# [ loss: 1.6243, acc: 0.5451 ]

# %% [markdown]
# ### Model 2. 3  Dense(Leaky RELU)

# %%
# 모델 설정
model = Sequential()
model.add(Dense(256, input_dim=11))
model.add(LeakyReLU(alpha=0.2))
model.add(Dense(128))
model.add(LeakyReLU(alpha=0.2))
model.add(Dense(64))
model.add(LeakyReLU(alpha=0.2))
model.add(Dense(10, activation='softmax'))
model.summary()

#모델 컴파일
model.compile(loss='categorical_crossentropy',
              optimizer='adam',
              metrics=['accuracy'])

# 모델 실행
model.fit(X_train, y_train, epochs=500, batch_size=100)

# 결과 출력
print("\n Accuracy: %.4f" % (model.evaluate(X_train, y_train)[1]))
# Out:
# _________________________________________________________________
# Layer (type)                 Output Shape              Param #
# ...
# dense_29 (Dense)             (None, 256)               3072
# _________________________________________________________________
# leaky_re_lu_7 (LeakyReLU)    (None, 256)               0
# _________________________________________________________________
# dense_30 (Dense)             (None, 128)               32896
# _________________________________________________________________
# leaky_re_lu_8 (LeakyReLU)    (None, 128)               0
# _________________________________________________________________
# dense_31 (Dense)             (None, 64)                8256
# _________________________________________________________________
# leaky_re_lu_9 (LeakyReLU)    (None, 64)                0
# _________________________________________________________________
# dense_32 (Dense)             (None, 10)                650
# ...
# Total params: 44,874
# ...

# %%
loss, acc = model.evaluate(X_test, y_test)
print('[ loss: %.4f, acc: %.4f ]' % (loss, acc))
# Out:
# 1950/1950 [==============================] - 0s 35us/step
# [ loss: 1.3916, acc: 0.5554 ]

# %% [markdown]
# ### Model 3. 5 Dense(Leaky RELU) + Validation_split

# %%
# 모델 설정
model = Sequential()
model.add(Dense(256, input_dim=11))
model.add(LeakyReLU(alpha=0.2))
model.add(Dense(128))
model.add(LeakyReLU(alpha=0.2))
model.add(Dense(64))
model.add(LeakyReLU(alpha=0.2))
model.add(Dense(10, activation='softmax'))
model.summary()

#모델 컴파일
model.compile(loss='categorical_crossentropy',
              optimizer='adam',
              metrics=['accuracy'])

# 모델 실행
model.fit(X_train, y_train, epochs=500, batch_size=100, validation_split=0.1)

# 결과 출력
print("\n Accuracy: %.4f" % (model.evaluate(X_train, y_train)[1]))
# Out:
# _________________________________________________________________
# Layer (type)                 Output Shape              Param #
# ...
# dense_33 (Dense)             (None, 256)               3072
# _________________________________________________________________
# leaky_re_lu_10 (LeakyReLU)   (None, 256)               0
# _________________________________________________________________
# dense_34 (Dense)             (None, 128)               32896
# _________________________________________________________________
# leaky_re_lu_11 (LeakyReLU)   (None, 128)               0
# _________________________________________________________________
# dense_35 (Dense)             (None, 64)                8256
# _________________________________________________________________
# leaky_re_lu_12 (LeakyReLU)   (None, 64)                0
# _________________________________________________________________
# dense_36 (Dense)             (None, 10)                650
# ...
# Total params: 44,874
# ...

# %%
loss, acc = model.evaluate(X_test, y_test)
print('[ loss: %.4f, acc: %.4f ]' % (loss, acc))
# Out:
# 1950/1950 [==============================] - 0s 41us/step
# [ loss: 1.4874, acc: 0.5246 ]

# %% [markdown]
# ### Model 4. 5 Dense(Leaky RELU) + Batch_size(50)

# %%
# 모델 설정
model = Sequential()
model.add(Dense(256, input_dim=11))
model.add(LeakyReLU(alpha=0.2))
model.add(Dense(128))
model.add(LeakyReLU(alpha=0.2))
model.add(Dense(64))
model.add(LeakyReLU(alpha=0.2))
model.add(Dense(10, activation='softmax'))
model.summary()

#모델 컴파일
model.compile(loss='categorical_crossentropy',
              optimizer='adam',
              metrics=['accuracy'])

# 모델 실행
model.fit(X_train, y_train, epochs=500, batch_size=50, validation_split=0.1)

# 결과 출력
print("\n Accuracy: %.4f" % (model.evaluate(X_train, y_train)[1]))
# Out:
# _________________________________________________________________
# Layer (type)                 Output Shape              Param #
# ...
# dense_41 (Dense)             (None, 256)               3072
# _________________________________________________________________
# leaky_re_lu_16 (LeakyReLU)   (None, 256)               0
# _________________________________________________________________
# dense_42 (Dense)             (None, 128)               32896
# _________________________________________________________________
# leaky_re_lu_17 (LeakyReLU)   (None, 128)               0
# _________________________________________________________________
# dense_43 (Dense)             (None, 64)                8256
# _________________________________________________________________
# leaky_re_lu_18 (LeakyReLU)   (None, 64)                0
# _________________________________________________________________
# dense_44 (Dense)             (None, 10)                650
# ...
# Total params: 44,874
# ...

# %%
loss, acc = model.evaluate(X_test, y_test)
print('[ loss: %.4f, acc: %.4f ]' % (loss, acc))
# Out:
# 1950/1950 [==============================] - 0s 42us/step
# [ loss: 1.6563, acc: 0.5421 ]

# %% [markdown]
# ### Model 4. 5 Dense(Leaky RELU) + Batch_size(50) + Dropout(0.2)

# %%
# 모델 설정
model = Sequential()
model.add(Dense(256, input_dim=11))
model.add(LeakyReLU(alpha=0.2))
model.add(Dropout(0.2))
model.add(Dense(128))
model.add(LeakyReLU(alpha=0.2))
model.add(Dropout(0.2))
model.add(Dense(64))
model.add(LeakyReLU(alpha=0.2))
model.add(Dropout(0.2))
model.add(Dense(10, activation='softmax'))
model.summary()

#모델 컴파일
model.compile(loss='categorical_crossentropy',
              optimizer='adam',
              metrics=['accuracy'])

# 모델 실행
model.fit(X_train, y_train, epochs=500, batch_size=50, validation_split=0.1)

# 결과 출력
print("\n Accuracy: %.4f" % (model.evaluate(X_train, y_train)[1]))
# Out:
# _________________________________________________________________
# Layer (type)                 Output Shape              Param #
# ...
# dense_45 (Dense)             (None, 256)               3072
# _________________________________________________________________
# leaky_re_lu_19 (LeakyReLU)   (None, 256)               0
# _________________________________________________________________
# dropout_16 (Dropout)         (None, 256)               0
# _________________________________________________________________
# dense_46 (Dense)             (None, 128)               32896
# _________________________________________________________________
# leaky_re_lu_20 (LeakyReLU)   (None, 128)               0
# _________________________________________________________________
# dropout_17 (Dropout)         (None, 128)               0
# _________________________________________________________________
# dense_47 (Dense)             (None, 64)                8256
# ...

# %%
loss, acc = model.evaluate(X_test, y_test)
print('[ loss: %.4f, acc: %.4f ]' % (loss, acc))
# Out:
# 1950/1950 [==============================] - 0s 44us/step
# [ loss: 1.0701, acc: 0.5554 ]

# %% [markdown]
# ### Model 5. 5 Dense(Leaky RELU) + Batch_size(50) + Dropout(0.1)

# %%
# 모델 설정
model = Sequential()
model.add(Dense(256, input_dim=11))
model.add(LeakyReLU(alpha=0.2))
model.add(Dropout(0.1))
model.add(Dense(128))
model.add(LeakyReLU(alpha=0.2))
model.add(Dropout(0.1))
model.add(Dense(64))
model.add(LeakyReLU(alpha=0.2))
model.add(Dropout(0.1))
model.add(Dense(10, activation='softmax'))
model.summary()

#모델 컴파일
model.compile(loss='categorical_crossentropy',
              optimizer='adam',
              metrics=['accuracy'])

# 모델 실행
model.fit(X_train, y_train, epochs=500, batch_size=50, validation_split=0.1)

# 결과 출력
print("\n Accuracy: %.4f" % (model.evaluate(X_train, y_train)[1]))
# Out:
# _________________________________________________________________
# Layer (type)                 Output Shape              Param #
# ...
# dense_49 (Dense)             (None, 256)               3072
# _________________________________________________________________
# leaky_re_lu_22 (LeakyReLU)   (None, 256)               0
# _________________________________________________________________
# dropout_19 (Dropout)         (None, 256)               0
# _________________________________________________________________
# dense_50 (Dense)             (None, 128)               32896
# _________________________________________________________________
# leaky_re_lu_23 (LeakyReLU)   (None, 128)               0
# _________________________________________________________________
# dropout_20 (Dropout)         (None, 128)               0
# _________________________________________________________________
# dense_51 (Dense)             (None, 64)                8256
# ...

# %%
loss, acc = model.evaluate(X_test, y_test)
print('[ loss: %.4f, acc: %.4f ]' % (loss, acc))
# Out:
# 1950/1950 [==============================] - 0s 44us/step
# [ loss: 1.1153, acc: 0.5585 ]

# %%
n = np.random.randint(0, len(X_test))

predictions = model.predict(X_test[n].reshape(1,11))
print("[Idx:%d] [%d, %d]" % (n, np.argmax(predictions), list(y_test[n]).index(1.0)))
# Out:
# [Idx:1521] [6, 6]
